# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import numpy as np
import pandas as pd
import os
from tqdm import tqdm

# %% [markdown]
# # Prepare Data

# %%
data_dir = "../../InterpolationBaseline/data/Oct0123_Dec3123/"
data_files = [file for file in os.listdir(data_dir) if file.endswith(".csv")]
data_oct = []
data_nov = []
data_dec = []

for file in data_files:
    df = pd.read_csv(data_dir + file)
    df.loc[df["pm25"] < 0, "pm25"] = 0

    # remove outliers
    if df["pm25"].max() > 500:
        print("Outlier dropped")
        continue

    # decompose timestamp
    df["timestamp"] = pd.to_datetime(df["timestamp"], format="mixed")
    df["hour"] = df["timestamp"].dt.hour
    df["day"] = df["timestamp"].dt.day
    df["month"] = df["timestamp"].dt.month
    df["year"] = df["timestamp"].dt.year

    df = df.loc[:, ["year", "month", "day", "hour", "pm25", "longitude", "latitude"]]
    df = df.groupby(["year", "month", "day", "hour"]).mean().reset_index(drop=False)

    if len(df) < 24 * (31 + 30 + 31):
        print("Missing Data")
        continue
    else:
        df_oct = df[df["month"] == 10]
        df_nov = df[df["month"] == 11]
        df_dec = df[df["month"] == 12]
        data_oct.append(df_oct.loc[:, ["pm25", "longitude", "latitude"]].to_numpy())
        data_nov.append(df_nov.loc[:, ["pm25", "longitude", "latitude"]].to_numpy())
        data_dec.append(df_dec.loc[:, ["pm25", "longitude", "latitude"]].to_numpy())

data_oct = np.array(data_oct)
data_nov = np.array(data_nov)
data_dec = np.array(data_dec)
print(data_oct.shape, data_nov.shape, data_dec.shape)
# Out:
# Outlier dropped
# Missing Data
# Outlier dropped
# Outlier dropped
# Missing Data
# Outlier dropped
# Outlier dropped
# Missing Data
# Outlier dropped
# Missing Data
# Outlier dropped
# Missing Data
# Outlier dropped
# Outlier dropped
# Outlier dropped
# (36, 744, 3) (36, 720, 3) (36, 744, 3)

# %%
data_dir = "../../InterpolationBaseline/data/Jan0124_Jan2924/"
data_files = [file for file in os.listdir(data_dir) if file.endswith(".csv")]
data_jan = []

for file in data_files:
    df = pd.read_csv(data_dir + file)
    df.loc[df["pm25"] < 0, "pm25"] = 0

    # remove outliers
    if df["pm25"].max() > 500:
        print("Outlier dropped")
        continue

    # decompose timestamp
    df["timestamp"] = pd.to_datetime(df["timestamp"], format="mixed")
    df["hour"] = df["timestamp"].dt.hour
    df["day"] = df["timestamp"].dt.day
    df["month"] = df["timestamp"].dt.month
    df["year"] = df["timestamp"].dt.year

    df = df.loc[:, ["year", "month", "day", "hour", "pm25", "longitude", "latitude"]]
    df = df.groupby(["year", "month", "day", "hour"]).mean().reset_index(drop=False)

    if len(df) < 24 * 30:
        print("Missing Data")
        continue
    else:
        data_jan.append(df.loc[:, ["pm25", "longitude", "latitude"]].to_numpy())

data_jan = np.array(data_jan)
print(data_jan.shape)
# Out:
# Outlier dropped
# Outlier dropped
# Outlier dropped
# Outlier dropped
# Outlier dropped
# Outlier dropped
# Missing Data
# (45, 722, 3)

# %%
class Geo_LSTM_Dataset(Dataset):
    def __init__(self, X, Y):
        self.X = X
        self.Y = Y
            
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, index):
        return self.X[index], self.Y[index]
    
def construct_dataloader(data, seed=42, window_size=24, batch_size=256):
    np.random.seed(seed)

    n_stations = data.shape[0]
    permutation = np.random.permutation(n_stations)
    data_train = data[permutation[:int(n_stations * 0.8)]]
    data_test = data[permutation[int(n_stations * 0.8):]]
    X_train = []
    Y_train = []
    X_test = []
    Y_test = []

    # construct training data
    for label_index in range(len(data_train)):
        X = np.concatenate([data_train[:label_index], data_train[label_index + 1:]], axis=0)
        Y = data_train[label_index: label_index+1]
        RLat = torch.from_numpy(Y[0, 0, 1] - X[:, 0, 1])
        RLon = torch.from_numpy(Y[0, 0, 2] - X[:, 0, 2])
        for t in range(window_size-1, X.shape[1]):
            history_readings = torch.from_numpy(X[:, t-window_size+1:t+1, 0])
            target_reading = Y[0, t, 0]
            X_train.append((history_readings, RLat, RLon))
            Y_train.append(target_reading)
    Y_train = torch.tensor(Y_train)
    train_dataest = Geo_LSTM_Dataset(X_train, Y_train)
    train_loader = DataLoader(train_dataest, batch_size=batch_size, shuffle=True)

    # construct testing data
    for label_index in range(len(data_test)):
        RLat = torch.from_numpy(data_test[label_index, 0, 1] - data_train[:, 0, 1])
        RLon = torch.from_numpy(data_test[label_index, 0, 2] - data_train[:, 0, 2])
        for t in range(window_size-1, data_test.shape[1]):
            history_readings = torch.from_numpy(data_train[:, t-window_size+1:t+1, 0])
            target_reading = data_test[label_index, t, 0]
            X_test.append((history_readings, RLat, RLon))
            Y_test.append(target_reading)
    Y_test = torch.tensor(Y_test)
    test_dataest = Geo_LSTM_Dataset(X_test, Y_test)
    test_loader = DataLoader(test_dataest, batch_size=batch_size, shuffle=False)

    return train_loader, test_loader

# %% [markdown]
# # Construct Model

# %%
class Geo_Layer(nn.Module):
    def __init__(self, K=4):
        super(Geo_Layer, self).__init__()
        self.K = K

    def forward(self, X):
        # history_readings: (batch_size, n_stations, window_size)
        # RLat: (batch_size, n_stations)
        # RLon: (batch_size, n_stations)
        history_readings, RLat, RLon = X
        batch_size, n_stations, window_size = history_readings.shape

        # RDist, Rank, R_A: (batch_size, n_stations)
        RDist = torch.sqrt(RLat**2 + RLon**2)
        indice = torch.argsort(RDist)[:, :self.K]   # (batch_size, K)
        nearby_readings = history_readings[torch.arange(batch_size)[:, None], indice]

        return nearby_readings
    
class Geo_LSTM(nn.Module):
    def __init__(self, K=4, num_layers=4, hidden_size=128, fc_hidden=1024):
        super(Geo_LSTM, self).__init__()
        self.geo_layer = Geo_Layer(K)
        self.lstm = nn.LSTM(input_size=K, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True)
        self.fc = nn.Sequential(*[
            nn.Linear(hidden_size, fc_hidden),
            nn.ReLU(),
            nn.Linear(fc_hidden, 1)
        ])

    def forward(self, X):
        # nearby_readings: (batch_size, window_size, K)
        nearby_readings = self.geo_layer(X).permute(0, 2, 1).float()
        # output: (batch_size, window_size, hidden_size) -> (batch_size, 1)
        output, _ = self.lstm(nearby_readings)
        output = self.fc(output[:, -1, :]).squeeze()
        return output

# %% [markdown]
# # Train

# %%
batch_size = 32
epochs = 100
lr = 1e-3

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## October

# %%
geo_lstm = Geo_LSTM().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(geo_lstm.parameters(), lr=lr)
train_loader, test_loader = construct_dataloader(data_oct, seed=42, window_size=24, batch_size=batch_size)
best_loss = 1e10
save_path = f"./model_weights/geolstm_oct.pt"
for epoch in range(epochs):
    geo_lstm.train()
    for X, Y in train_loader:
        X = (X[0].to(device), X[1].to(device), X[2].to(device))
        Y = Y.to(device)
        optimizer.zero_grad()
        Y_pred = geo_lstm(X)
        loss = criterion(Y_pred, Y.float())
        loss.backward()
        optimizer.step()

    # evaluate on train test set
    with torch.no_grad():
        train_loss = 0
        for X, Y in train_loader:
            X = (X[0].to(device), X[1].to(device), X[2].to(device))
            Y = Y.to(device)
            Y_pred = geo_lstm(X)
            train_loss += criterion(Y_pred, Y.float()).item()
        train_loss /= len(train_loader)

        test_loss = 0
        for X, Y in test_loader:
            X = (X[0].to(device), X[1].to(device), X[2].to(device))
            Y = Y.to(device)
            Y_pred = geo_lstm(X)
            test_loss += criterion(Y_pred, Y.float()).item()
        test_loss /= len(test_loader)

    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}")

    # save model
    if test_loss < best_loss:
        best_loss = test_loss
        torch.save(geo_lstm.state_dict(), save_path)
        print(f"Model saved at {save_path}")
# Out:
# Epoch 1/100, Train Loss: 12.3159, Test Loss: 18.7283
# Model saved at ./model_weights/geolstm_oct.pt
# Epoch 2/100, Train Loss: 9.4421, Test Loss: 12.6372
# Model saved at ./model_weights/geolstm_oct.pt
# Epoch 3/100, Train Loss: 8.4362, Test Loss: 14.8366
# Epoch 4/100, Train Loss: 7.6994, Test Loss: 12.4877
# Model saved at ./model_weights/geolstm_oct.pt
# Epoch 5/100, Train Loss: 8.1927, Test Loss: 11.6048
# Model saved at ./model_weights/geolstm_oct.pt
# Epoch 6/100, Train Loss: 7.5247, Test Loss: 16.3910
# Epoch 7/100, Train Loss: 7.5953, Test Loss: 17.3382
# Epoch 8/100, Train Loss: 6.2702, Test Loss: 13.2843
# Epoch 9/100, Train Loss: 7.3553, Test Loss: 11.5642
# Model saved at ./model_weights/geolstm_oct.pt
# Epoch 10/100, Train Loss: 7.1320, Test Loss: 12.8134
# Epoch 11/100, Train Loss: 6.5325, Test Loss: 13.4231
# Epoch 12/100, Train Loss: 6.3462, Test Loss: 17.3798
# Epoch 13/100, Train Loss: 5.8520, Test Loss: 12.4632
# Epoch 14/100, Train Loss: 5.9397, Test Loss: 12.8463
# Epoch 15/100, Train Loss: 5.2952, Test Loss: 15.3978
# Epoch 16/100, Train Loss: 5.4132, Test Loss: 15.6908
# Epoch 17/100, Train Loss: 4.8964, Test Loss: 13.9823
# Epoch 18/100, Train Loss: 5.3555, Test Loss: 15.3214
# Epoch 19/100, Train Loss: 5.3234, Test Loss: 14.7573
# Epoch 20/100, Train Loss: 4.5817, Test Loss: 14.0132
# Epoch 21/100, Train Loss: 4.6591, Test Loss: 13.1438
# Epoch 22/100, Train Loss: 4.9244, Test Loss: 14.8786
# Epoch 23/100, Train Loss: 15.9794, Test Loss: 25.9457
# Epoch 24/100, Train Loss: 4.8369, Test Loss: 15.4253
# Epoch 25/100, Train Loss: 4.2359, Test Loss: 16.4914
# Epoch 26/100, Train Loss: 4.7349, Test Loss: 14.7809
# Epoch 27/100, Train Loss: 4.8417, Test Loss: 14.5682
# Epoch 28/100, Train Loss: 4.2908, Test Loss: 14.8096
# Epoch 29/100, Train Loss: 3.1017, Test Loss: 15.1508
# Epoch 30/100, Train Loss: 3.5905, Test Loss: 15.0947
# Epoch 31/100, Train Loss: 3.5802, Test Loss: 15.2701
# Epoch 32/100, Train Loss: 4.9980, Test Loss: 13.4468
# Epoch 33/100, Train Loss: 3.6953, Test Loss: 15.3142
# Epoch 34/100, Train Loss: 3.3278, Test Loss: 15.2868
# Epoch 35/100, Train Loss: 3.1628, Test Loss: 16.7111
# Epoch 36/100, Train Loss: 3.6985, Test Loss: 15.4328
# Epoch 83/100, Train Loss: 1.2204, Test Loss: 14.3345
# Epoch 84/100, Train Loss: 1.0320, Test Loss: 14.4236
# Epoch 85/100, Train Loss: 1.1257, Test Loss: 14.3947
# Epoch 86/100, Train Loss: 1.1344, Test Loss: 14.5075
# Epoch 87/100, Train Loss: 1.2759, Test Loss: 15.0953
# Epoch 88/100, Train Loss: 1.6886, Test Loss: 14.3983
# Epoch 89/100, Train Loss: 1.5379, Test Loss: 14.0257
# Epoch 90/100, Train Loss: 1.1206, Test Loss: 14.3813
# Epoch 91/100, Train Loss: 0.9637, Test Loss: 13.6063
# Epoch 92/100, Train Loss: 0.9606, Test Loss: 14.0995
# Epoch 93/100, Train Loss: 0.9013, Test Loss: 15.1029
# Epoch 94/100, Train Loss: 1.1277, Test Loss: 14.9687
# Epoch 95/100, Train Loss: 0.8827, Test Loss: 14.7781
# Epoch 96/100, Train Loss: 1.5342, Test Loss: 14.2621
# Epoch 97/100, Train Loss: 4.3895, Test Loss: 13.6253
# Epoch 98/100, Train Loss: 0.9200, Test Loss: 15.0541
# Epoch 99/100, Train Loss: 0.7814, Test Loss: 14.8997
# Epoch 100/100, Train Loss: 0.7311, Test Loss: 13.7622

# %%
Y_pred_all = []
Y_true_all = []
geo_lstm.load_state_dict(torch.load(save_path))
geo_lstm.eval()
with torch.no_grad():
    for X, Y in test_loader:
        X = (X[0].to(device), X[1].to(device), X[2].to(device))
        Y = Y.to(device)
        Y_pred = geo_lstm(X)
        Y_pred_all.append(Y_pred.cpu().numpy())
        Y_true_all.append(Y.cpu().numpy())
Y_pred_all = np.concatenate(Y_pred_all)
Y_true_all = np.concatenate(Y_true_all)
RMSE = np.sqrt(np.mean((Y_pred_all - Y_true_all)**2))
CVRMSE = RMSE / Y_true_all.mean()
MAE = np.mean(np.abs(Y_pred_all - Y_true_all))
R2 = 1 - np.sum((Y_pred_all - Y_true_all)**2) / np.sum((Y_true_all - Y_true_all.mean())**2)
print("RMSE:", RMSE)
print("CVRMSE:", CVRMSE)
print("MAE:", MAE)
print("R2:", R2)
# Out:
# RMSE: 3.3997461940033276
# CVRMSE: 0.3301037150709755
# MAE: 2.497493799006621
# R2: 0.6297184838299943

# %% [markdown]
# ## November

# %%
geo_lstm = Geo_LSTM().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(geo_lstm.parameters(), lr=lr)
train_loader, test_loader = construct_dataloader(data_nov, seed=42, window_size=24, batch_size=batch_size)
best_loss = 1e10
save_path = f"./model_weights/geolstm_nov.pt"
for epoch in range(epochs):
    geo_lstm.train()
    for X, Y in train_loader:
        X = (X[0].to(device), X[1].to(device), X[2].to(device))
        Y = Y.to(device)
        optimizer.zero_grad()
        Y_pred = geo_lstm(X)
        loss = criterion(Y_pred, Y.float())
        loss.backward()
        optimizer.step()

    # evaluate on train test set
    with torch.no_grad():
        train_loss = 0
        for X, Y in train_loader:
            X = (X[0].to(device), X[1].to(device), X[2].to(device))
            Y = Y.to(device)
            Y_pred = geo_lstm(X)
            train_loss += criterion(Y_pred, Y.float()).item()
        train_loss /= len(train_loader)

        test_loss = 0
        for X, Y in test_loader:
            X = (X[0].to(device), X[1].to(device), X[2].to(device))
            Y = Y.to(device)
            Y_pred = geo_lstm(X)
            test_loss += criterion(Y_pred, Y.float()).item()
        test_loss /= len(test_loader)

    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}")

    # save model
    if test_loss < best_loss:
        best_loss = test_loss
        torch.save(geo_lstm.state_dict(), save_path)
        print(f"Model saved at {save_path}")
# Out:
# Epoch 1/100, Train Loss: 13.1665, Test Loss: 23.3029
# Model saved at ./model_weights/geolstm_nov.pt
# Epoch 2/100, Train Loss: 12.1570, Test Loss: 18.7262
# Model saved at ./model_weights/geolstm_nov.pt
# Epoch 3/100, Train Loss: 14.6990, Test Loss: 17.0579
# Model saved at ./model_weights/geolstm_nov.pt
# Epoch 4/100, Train Loss: 11.9829, Test Loss: 20.0668
# Epoch 5/100, Train Loss: 10.0619, Test Loss: 18.1488
# Epoch 6/100, Train Loss: 9.5325, Test Loss: 22.5031
# Epoch 7/100, Train Loss: 9.5475, Test Loss: 23.7483
# Epoch 8/100, Train Loss: 8.7780, Test Loss: 26.1758
# Epoch 9/100, Train Loss: 8.7119, Test Loss: 19.4176
# Epoch 10/100, Train Loss: 8.2438, Test Loss: 23.8853
# Epoch 11/100, Train Loss: 6.4288, Test Loss: 22.0219
# Epoch 12/100, Train Loss: 6.6705, Test Loss: 22.5354
# Epoch 13/100, Train Loss: 7.6512, Test Loss: 19.5138
# Epoch 14/100, Train Loss: 6.0378, Test Loss: 23.5713
# Epoch 15/100, Train Loss: 5.7781, Test Loss: 22.5898
# Epoch 16/100, Train Loss: 5.4623, Test Loss: 22.8205
# Epoch 17/100, Train Loss: 5.7160, Test Loss: 20.2649
# Epoch 18/100, Train Loss: 4.8255, Test Loss: 24.0712
# Epoch 19/100, Train Loss: 4.9754, Test Loss: 21.8231
# Epoch 20/100, Train Loss: 4.7874, Test Loss: 21.7487
# Epoch 21/100, Train Loss: 6.1347, Test Loss: 24.3370
# Epoch 22/100, Train Loss: 4.8760, Test Loss: 21.9646
# Epoch 23/100, Train Loss: 4.9099, Test Loss: 20.8525
# Epoch 24/100, Train Loss: 4.2502, Test Loss: 21.9711
# Epoch 25/100, Train Loss: 4.2331, Test Loss: 23.1024
# Epoch 26/100, Train Loss: 4.2457, Test Loss: 21.7378
# Epoch 27/100, Train Loss: 4.4400, Test Loss: 26.5420
# Epoch 28/100, Train Loss: 3.8316, Test Loss: 26.7219
# Epoch 29/100, Train Loss: 3.9842, Test Loss: 27.0483
# Epoch 30/100, Train Loss: 4.5100, Test Loss: 30.4615
# Epoch 31/100, Train Loss: 4.3480, Test Loss: 21.6801
# Epoch 32/100, Train Loss: 3.6530, Test Loss: 25.9411
# Epoch 33/100, Train Loss: 3.5533, Test Loss: 28.9300
# Epoch 34/100, Train Loss: 3.1757, Test Loss: 24.9515
# Epoch 35/100, Train Loss: 3.5639, Test Loss: 25.8390
# Epoch 36/100, Train Loss: 2.6881, Test Loss: 25.9527
# Epoch 37/100, Train Loss: 3.5451, Test Loss: 21.8287
# Epoch 38/100, Train Loss: 2.8683, Test Loss: 21.6016
# Epoch 39/100, Train Loss: 2.5679, Test Loss: 25.2990
# Epoch 40/100, Train Loss: 2.6016, Test Loss: 24.8040
# Epoch 41/100, Train Loss: 2.6954, Test Loss: 26.9975
# Epoch 42/100, Train Loss: 3.9233, Test Loss: 24.1317
# Epoch 43/100, Train Loss: 2.3034, Test Loss: 24.4190
# Epoch 44/100, Train Loss: 2.3951, Test Loss: 24.4337
# Epoch 45/100, Train Loss: 2.2753, Test Loss: 23.9764
# Epoch 46/100, Train Loss: 2.2469, Test Loss: 25.9107
# Epoch 47/100, Train Loss: 1.9808, Test Loss: 23.1953
# Epoch 94/100, Train Loss: 0.6075, Test Loss: 22.0027
# Epoch 95/100, Train Loss: 0.5153, Test Loss: 22.6358
# Epoch 96/100, Train Loss: 0.4598, Test Loss: 22.0342
# Epoch 97/100, Train Loss: 0.7319, Test Loss: 21.8435
# Epoch 98/100, Train Loss: 0.5193, Test Loss: 23.0724
# Epoch 99/100, Train Loss: 0.9730, Test Loss: 23.4989
# Epoch 100/100, Train Loss: 0.4888, Test Loss: 24.3159

# %%
Y_pred_all = []
Y_true_all = []
geo_lstm.load_state_dict(torch.load(save_path))
geo_lstm.eval()
with torch.no_grad():
    for X, Y in test_loader:
        X = (X[0].to(device), X[1].to(device), X[2].to(device))
        Y = Y.to(device)
        Y_pred = geo_lstm(X)
        Y_pred_all.append(Y_pred.cpu().numpy())
        Y_true_all.append(Y.cpu().numpy())
Y_pred_all = np.concatenate(Y_pred_all)
Y_true_all = np.concatenate(Y_true_all)
RMSE = np.sqrt(np.mean((Y_pred_all - Y_true_all)**2))
CVRMSE = RMSE / Y_true_all.mean()
MAE = np.mean(np.abs(Y_pred_all - Y_true_all))
R2 = 1 - np.sum((Y_pred_all - Y_true_all)**2) / np.sum((Y_true_all - Y_true_all.mean())**2)
print("RMSE:", RMSE)
print("CVRMSE:", CVRMSE)
print("MAE:", MAE)
print("R2:", R2)
# Out:
# RMSE: 4.135922015085295
# CVRMSE: 0.3507384626961344
# MAE: 3.0058346139989216
# R2: 0.6898451418475822

# %% [markdown]
# ## December

# %%
geo_lstm = Geo_LSTM().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(geo_lstm.parameters(), lr=lr)
train_loader, test_loader = construct_dataloader(data_dec, seed=42, window_size=24, batch_size=batch_size)
best_loss = 1e10
save_path = f"./model_weights/geolstm_dec.pt"
for epoch in range(epochs):
    geo_lstm.train()
    for X, Y in train_loader:
        X = (X[0].to(device), X[1].to(device), X[2].to(device))
        Y = Y.to(device)
        optimizer.zero_grad()
        Y_pred = geo_lstm(X)
        loss = criterion(Y_pred, Y.float())
        loss.backward()
        optimizer.step()

    # evaluate on train test set
    with torch.no_grad():
        train_loss = 0
        for X, Y in train_loader:
            X = (X[0].to(device), X[1].to(device), X[2].to(device))
            Y = Y.to(device)
            Y_pred = geo_lstm(X)
            train_loss += criterion(Y_pred, Y.float()).item()
        train_loss /= len(train_loader)

        test_loss = 0
        for X, Y in test_loader:
            X = (X[0].to(device), X[1].to(device), X[2].to(device))
            Y = Y.to(device)
            Y_pred = geo_lstm(X)
            test_loss += criterion(Y_pred, Y.float()).item()
        test_loss /= len(test_loader)

    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}")

    # save model
    if test_loss < best_loss:
        best_loss = test_loss
        torch.save(geo_lstm.state_dict(), save_path)
        print(f"Model saved at {save_path}")
# Out:
# Epoch 1/100, Train Loss: 39.5002, Test Loss: 46.3392
# Model saved at ./model_weights/geolstm_dec.pt
# Epoch 2/100, Train Loss: 35.0820, Test Loss: 58.7885
# Epoch 3/100, Train Loss: 31.3726, Test Loss: 49.2513
# Epoch 4/100, Train Loss: 29.2579, Test Loss: 57.3970
# Epoch 5/100, Train Loss: 32.3218, Test Loss: 47.2197
# Epoch 6/100, Train Loss: 27.1399, Test Loss: 56.7607
# Epoch 7/100, Train Loss: 24.5790, Test Loss: 55.6579
# Epoch 8/100, Train Loss: 24.6962, Test Loss: 54.7171
# Epoch 9/100, Train Loss: 19.8901, Test Loss: 56.2535
# Epoch 10/100, Train Loss: 23.2248, Test Loss: 57.5621
# Epoch 11/100, Train Loss: 18.8124, Test Loss: 65.2794
# Epoch 12/100, Train Loss: 21.0860, Test Loss: 51.6954
# Epoch 13/100, Train Loss: 17.1062, Test Loss: 66.2862
# Epoch 60/100, Train Loss: 2.8228, Test Loss: 64.0801
# Epoch 61/100, Train Loss: 2.2785, Test Loss: 60.7588
# Epoch 62/100, Train Loss: 2.1221, Test Loss: 66.7240
# Epoch 63/100, Train Loss: 2.2349, Test Loss: 68.5107
# Epoch 64/100, Train Loss: 2.2790, Test Loss: 64.1563
# Epoch 65/100, Train Loss: 2.0720, Test Loss: 60.1222
# Epoch 66/100, Train Loss: 1.9700, Test Loss: 67.0396
# Epoch 67/100, Train Loss: 3.1370, Test Loss: 57.1540
# Epoch 68/100, Train Loss: 3.4487, Test Loss: 62.0907
# Epoch 69/100, Train Loss: 1.8286, Test Loss: 65.3997
# Epoch 70/100, Train Loss: 1.4784, Test Loss: 65.7992
# Epoch 71/100, Train Loss: 1.3067, Test Loss: 64.9986
# Epoch 72/100, Train Loss: 1.4504, Test Loss: 66.2070
# Epoch 73/100, Train Loss: 2.1798, Test Loss: 64.3901
# Epoch 74/100, Train Loss: 1.7936, Test Loss: 62.7229
# Epoch 75/100, Train Loss: 1.5922, Test Loss: 67.3940
# Epoch 76/100, Train Loss: 1.4795, Test Loss: 68.6711
# Epoch 77/100, Train Loss: 1.3872, Test Loss: 66.5257
# Epoch 78/100, Train Loss: 1.2886, Test Loss: 64.1575
# Epoch 79/100, Train Loss: 2.2833, Test Loss: 67.7565
# Epoch 80/100, Train Loss: 1.1258, Test Loss: 65.2385
# Epoch 81/100, Train Loss: 1.4472, Test Loss: 63.6372
# Epoch 82/100, Train Loss: 1.1816, Test Loss: 62.5497
# Epoch 83/100, Train Loss: 0.9833, Test Loss: 61.5846
# Epoch 84/100, Train Loss: 1.1715, Test Loss: 64.7522
# Epoch 85/100, Train Loss: 1.1585, Test Loss: 61.8590
# Epoch 86/100, Train Loss: 1.5973, Test Loss: 66.8784
# Epoch 87/100, Train Loss: 1.5916, Test Loss: 63.9459
# Epoch 88/100, Train Loss: 0.8009, Test Loss: 62.1370
# Epoch 89/100, Train Loss: 0.6677, Test Loss: 59.7203
# Epoch 90/100, Train Loss: 0.7765, Test Loss: 60.0916
# Epoch 91/100, Train Loss: 1.1632, Test Loss: 64.4529
# Epoch 92/100, Train Loss: 1.2824, Test Loss: 64.5799
# Epoch 93/100, Train Loss: 0.9874, Test Loss: 62.0939
# Epoch 94/100, Train Loss: 0.8726, Test Loss: 65.2551
# Epoch 95/100, Train Loss: 0.8534, Test Loss: 63.7965
# Epoch 96/100, Train Loss: 5.6637, Test Loss: 60.0070
# Epoch 97/100, Train Loss: 0.7674, Test Loss: 63.9283
# Epoch 98/100, Train Loss: 0.7555, Test Loss: 60.6812
# Epoch 99/100, Train Loss: 0.5951, Test Loss: 63.3972
# Epoch 100/100, Train Loss: 0.6534, Test Loss: 64.1132

# %%
Y_pred_all = []
Y_true_all = []
geo_lstm.load_state_dict(torch.load(save_path))
geo_lstm.eval()
with torch.no_grad():
    for X, Y in test_loader:
        X = (X[0].to(device), X[1].to(device), X[2].to(device))
        Y = Y.to(device)
        Y_pred = geo_lstm(X)
        Y_pred_all.append(Y_pred.cpu().numpy())
        Y_true_all.append(Y.cpu().numpy())
Y_pred_all = np.concatenate(Y_pred_all)
Y_true_all = np.concatenate(Y_true_all)
RMSE = np.sqrt(np.mean((Y_pred_all - Y_true_all)**2))
CVRMSE = RMSE / Y_true_all.mean()
MAE = np.mean(np.abs(Y_pred_all - Y_true_all))
R2 = 1 - np.sum((Y_pred_all - Y_true_all)**2) / np.sum((Y_true_all - Y_true_all.mean())**2)
print("RMSE:", RMSE)
print("CVRMSE:", CVRMSE)
print("MAE:", MAE)
print("R2:", R2)
# Out:
# RMSE: 6.82116797296474
# CVRMSE: 0.4050034760698666
# MAE: 4.724538655543015
# R2: 0.6606058691141251

# %% [markdown]
# ## January

# %%
geo_lstm = Geo_LSTM().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(geo_lstm.parameters(), lr=lr)
train_loader, test_loader = construct_dataloader(data_jan, seed=42, window_size=24, batch_size=batch_size)
best_loss = 1e10
save_path = f"./model_weights/geolstm_jan.pt"
for epoch in range(epochs):
    geo_lstm.train()
    for X, Y in train_loader:
        X = (X[0].to(device), X[1].to(device), X[2].to(device))
        Y = Y.to(device)
        optimizer.zero_grad()
        Y_pred = geo_lstm(X)
        loss = criterion(Y_pred, Y.float())
        loss.backward()
        optimizer.step()

    # evaluate on train test set
    with torch.no_grad():
        train_loss = 0
        for X, Y in train_loader:
            X = (X[0].to(device), X[1].to(device), X[2].to(device))
            Y = Y.to(device)
            Y_pred = geo_lstm(X)
            train_loss += criterion(Y_pred, Y.float()).item()
        train_loss /= len(train_loader)

        test_loss = 0
        for X, Y in test_loader:
            X = (X[0].to(device), X[1].to(device), X[2].to(device))
            Y = Y.to(device)
            Y_pred = geo_lstm(X)
            test_loss += criterion(Y_pred, Y.float()).item()
        test_loss /= len(test_loader)

    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}")

    # save model
    if test_loss < best_loss:
        best_loss = test_loss
        torch.save(geo_lstm.state_dict(), save_path)
        print(f"Model saved at {save_path}")
# Out:
# Epoch 1/100, Train Loss: 13.1094, Test Loss: 24.2545
# Model saved at ./model_weights/geolstm_jan.pt
# Epoch 2/100, Train Loss: 12.4818, Test Loss: 27.9262
# Epoch 3/100, Train Loss: 11.4570, Test Loss: 24.2141
# Model saved at ./model_weights/geolstm_jan.pt
# Epoch 4/100, Train Loss: 12.0604, Test Loss: 24.5899
# Epoch 5/100, Train Loss: 10.1727, Test Loss: 25.3175
# Epoch 6/100, Train Loss: 10.7114, Test Loss: 25.4317
# Epoch 7/100, Train Loss: 10.0561, Test Loss: 27.6288
# Epoch 8/100, Train Loss: 8.5764, Test Loss: 27.1946
# Epoch 9/100, Train Loss: 7.7720, Test Loss: 27.9569
# Epoch 10/100, Train Loss: 8.2450, Test Loss: 24.9531
# Epoch 11/100, Train Loss: 8.3144, Test Loss: 30.7069
# Epoch 12/100, Train Loss: 8.3164, Test Loss: 25.1912
# Epoch 13/100, Train Loss: 6.7367, Test Loss: 29.6212
# Epoch 14/100, Train Loss: 6.2207, Test Loss: 27.7666
# Epoch 15/100, Train Loss: 6.7318, Test Loss: 27.3778
# Epoch 16/100, Train Loss: 5.2372, Test Loss: 28.4683
# Epoch 17/100, Train Loss: 6.0171, Test Loss: 27.9554
# Epoch 18/100, Train Loss: 5.3676, Test Loss: 29.8824
# Epoch 19/100, Train Loss: 5.1357, Test Loss: 28.6491
# Epoch 20/100, Train Loss: 5.3653, Test Loss: 30.3004
# Epoch 21/100, Train Loss: 4.9124, Test Loss: 30.5150
# Epoch 22/100, Train Loss: 5.0464, Test Loss: 27.8784
# Epoch 23/100, Train Loss: 4.5641, Test Loss: 29.4921
# Epoch 24/100, Train Loss: 4.2140, Test Loss: 29.1569
# Epoch 25/100, Train Loss: 3.6633, Test Loss: 31.2393
# Epoch 26/100, Train Loss: 4.5248, Test Loss: 28.1922
# Epoch 27/100, Train Loss: 3.3409, Test Loss: 32.0006
# Epoch 28/100, Train Loss: 4.0294, Test Loss: 30.0255
# Epoch 29/100, Train Loss: 3.6194, Test Loss: 29.4105
# Epoch 30/100, Train Loss: 3.4128, Test Loss: 32.6271
# Epoch 31/100, Train Loss: 2.8975, Test Loss: 30.7409
# Epoch 32/100, Train Loss: 5.2638, Test Loss: 28.0345
# Epoch 33/100, Train Loss: 2.6060, Test Loss: 30.8388
# Epoch 34/100, Train Loss: 5.8704, Test Loss: 30.2947
# Epoch 35/100, Train Loss: 3.4397, Test Loss: 29.7172
# Epoch 36/100, Train Loss: 2.9320, Test Loss: 29.9770
# Epoch 37/100, Train Loss: 2.4288, Test Loss: 30.8604
# Epoch 38/100, Train Loss: 2.2446, Test Loss: 31.1774
# Epoch 39/100, Train Loss: 4.8746, Test Loss: 32.7835
# Epoch 40/100, Train Loss: 4.2701, Test Loss: 29.2855
# Epoch 41/100, Train Loss: 4.1474, Test Loss: 31.4386
# Epoch 42/100, Train Loss: 3.7228, Test Loss: 29.2515
# Epoch 43/100, Train Loss: 2.4361, Test Loss: 29.9714
# Epoch 44/100, Train Loss: 2.3966, Test Loss: 32.1446
# Epoch 45/100, Train Loss: 1.9660, Test Loss: 30.7104
# Epoch 46/100, Train Loss: 2.1081, Test Loss: 30.5310
# Epoch 47/100, Train Loss: 1.7632, Test Loss: 30.4515
# Epoch 48/100, Train Loss: 1.8568, Test Loss: 30.9919
# Epoch 49/100, Train Loss: 2.0500, Test Loss: 30.5829
# Epoch 50/100, Train Loss: 1.7093, Test Loss: 31.1345
# Epoch 51/100, Train Loss: 2.2175, Test Loss: 33.2934
# Epoch 52/100, Train Loss: 2.1331, Test Loss: 30.5674
# Epoch 53/100, Train Loss: 1.8804, Test Loss: 30.0253
# Epoch 54/100, Train Loss: 2.1949, Test Loss: 32.3689
# Epoch 55/100, Train Loss: 2.5963, Test Loss: 29.8004
# Epoch 56/100, Train Loss: 1.4988, Test Loss: 29.5966
# Epoch 57/100, Train Loss: 1.3494, Test Loss: 30.0039
# Epoch 58/100, Train Loss: 2.2865, Test Loss: 27.5839
# Epoch 59/100, Train Loss: 1.5208, Test Loss: 29.9202
# Epoch 60/100, Train Loss: 1.4707, Test Loss: 31.3075
# Epoch 61/100, Train Loss: 1.5126, Test Loss: 28.8189
# Epoch 62/100, Train Loss: 1.2565, Test Loss: 28.7926
# Epoch 63/100, Train Loss: 1.7579, Test Loss: 31.1047
# Epoch 64/100, Train Loss: 1.1375, Test Loss: 31.1302
# Epoch 65/100, Train Loss: 1.0971, Test Loss: 31.1712
# Epoch 66/100, Train Loss: 1.0617, Test Loss: 28.1395
# Epoch 67/100, Train Loss: 0.9575, Test Loss: 29.9575
# Epoch 68/100, Train Loss: 2.4990, Test Loss: 30.6070
# Epoch 69/100, Train Loss: 1.1266, Test Loss: 29.9110
# Epoch 70/100, Train Loss: 0.9709, Test Loss: 31.2091
# Epoch 71/100, Train Loss: 0.7035, Test Loss: 31.3683
# Epoch 72/100, Train Loss: 0.9899, Test Loss: 31.6239
# Epoch 73/100, Train Loss: 1.0214, Test Loss: 29.7009
# Epoch 74/100, Train Loss: 0.8894, Test Loss: 30.9088
# Epoch 75/100, Train Loss: 1.0069, Test Loss: 29.7923
# Epoch 76/100, Train Loss: 1.3863, Test Loss: 30.1677
# Epoch 77/100, Train Loss: 1.8079, Test Loss: 31.1866
# Epoch 78/100, Train Loss: 2.6956, Test Loss: 30.6786
# Epoch 79/100, Train Loss: 0.8326, Test Loss: 30.4562
# Epoch 80/100, Train Loss: 0.6769, Test Loss: 30.6328
# Epoch 81/100, Train Loss: 0.5461, Test Loss: 30.8983
# Epoch 82/100, Train Loss: 0.5294, Test Loss: 30.4731
# Epoch 83/100, Train Loss: 0.7767, Test Loss: 29.7707
# Epoch 84/100, Train Loss: 0.5981, Test Loss: 30.6785
# Epoch 85/100, Train Loss: 0.4850, Test Loss: 29.9229
# Epoch 86/100, Train Loss: 0.9389, Test Loss: 30.0570
# Epoch 87/100, Train Loss: 0.9471, Test Loss: 31.3973
# Epoch 88/100, Train Loss: 0.7914, Test Loss: 29.6872
# Epoch 89/100, Train Loss: 0.5022, Test Loss: 30.0977
# Epoch 90/100, Train Loss: 0.6786, Test Loss: 29.6913
# Epoch 91/100, Train Loss: 0.8907, Test Loss: 30.1031
# Epoch 92/100, Train Loss: 0.3972, Test Loss: 30.0581
# Epoch 93/100, Train Loss: 0.3869, Test Loss: 30.0604
# Epoch 94/100, Train Loss: 0.4213, Test Loss: 29.3511
# Epoch 95/100, Train Loss: 0.6028, Test Loss: 30.7227
# Epoch 96/100, Train Loss: 0.7898, Test Loss: 31.8035
# Epoch 97/100, Train Loss: 0.5245, Test Loss: 29.4849
# Epoch 98/100, Train Loss: 0.3321, Test Loss: 29.7416
# Epoch 99/100, Train Loss: 0.3465, Test Loss: 30.9178
# Epoch 100/100, Train Loss: 0.3383, Test Loss: 29.9001

# %%
Y_pred_all = []
Y_true_all = []
geo_lstm.load_state_dict(torch.load(save_path))
geo_lstm.eval()
with torch.no_grad():
    for X, Y in test_loader:
        X = (X[0].to(device), X[1].to(device), X[2].to(device))
        Y = Y.to(device)
        Y_pred = geo_lstm(X)
        Y_pred_all.append(Y_pred.cpu().numpy())
        Y_true_all.append(Y.cpu().numpy())
Y_pred_all = np.concatenate(Y_pred_all)
Y_true_all = np.concatenate(Y_true_all)
RMSE = np.sqrt(np.mean((Y_pred_all - Y_true_all)**2))
CVRMSE = RMSE / Y_true_all.mean()
MAE = np.mean(np.abs(Y_pred_all - Y_true_all))
R2 = 1 - np.sum((Y_pred_all - Y_true_all)**2) / np.sum((Y_true_all - Y_true_all.mean())**2)
print("RMSE:", RMSE)
print("CVRMSE:", CVRMSE)
print("MAE:", MAE)
print("R2:", R2)
# Out:
# RMSE: 4.925393149814979
# CVRMSE: 0.4488830993025483
# MAE: 3.514295097989502
# R2: 0.7054906185234536
